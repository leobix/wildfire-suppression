# %%
using JuMP, Gurobi

# %% [markdown]
# # First we define main parameters

# %%
#Constant of the problem
n_region = 6
T = 6 #We consider a 6 hour problem
VE = 10
R = [VE for i in 1:T] #Maximum vehicles available (randomly chose atm)
WT = 2 #weight for incident state

#Parameters that we fix for the algorithm
DELTA = 60 #Units of time period
sim_periods = 60 #Time periods of discretization in the SIR simulation
sim_time = DELTA/sim_periods #Used so that if we discretize at very granular time, the cost doesn't grow too much
DIS = 0.01 #Discreztization gap for creating the states-space
espilon = 0.0000001 #Error term
weight = [1.00 for i in  1:n_region] #Weight of the region i
DP_gap = 0.00001
negative_column = [false]
range_it = [[[0, VE] for t in 1:T] for n in 1:n_region]
Tot_plans = 500000
record_now = [1]
record_end = [1]
NCOLB = 5000
lb_node = [0.0 for n in 1:NCOLB]
pre_node = [1 for n in 1:NCOLB]
sign_node = [true for n in 1:NCOLB]
thre_node = [[1, 1, 1.0] for n in 1:NCOLB]
error_fra = 0.00000001
cur_node = [1]
tot_node = [0]
UB = [Inf]
LB = [-Inf]
already_optimized = [false]
null_constraints = []
vehicles_constraints = []
region_constraints = []
new_cg = [false];

# %%
plan_set = [[[0 for t in 1:T] for i in 1:n_region], 
            [[1 for t in 1:T] for i in 1:n_region], 
            [[2 for t in 1:T] for i in 1:n_region]]

n_plan = length(plan_set)
;

# %%
#SIR parameters
alpha = [0.001]
betaK = [0.17]
Lambda = [0.0001]
mu = [0.1]
for i in 2:n_region
    push!(alpha, alpha[i-1]*0.95)
    push!(betaK, betaK[i-1]*0.95)
    push!(Lambda, Lambda[i-1]*0.95)
    push!(mu, mu[i-1]*0.95)
end

# %%
cost_p = [1.0 for p in 1:Tot_plans]
vehn_pt = [[1 for t in 1:T] for p in 1:Tot_plans]
regn_p = [0 for t in 1:Tot_plans]

infea_p = [true for p in 1:Tot_plans];

# %%
#Initial State for each region

initial_state = [[0.99, 0.01, 0, 0]]
for r in 2:n_region
    f0_r = round(last(initial_state)[1] - 0.06, digits = 2)
    c0_r = round(last(initial_state)[2] + 0.03, digits = 2)
    r0_r = round(last(initial_state)[3] + 0.02, digits = 2)
    h0_r = round(last(initial_state)[4] + 0.01, digits = 2)
    push!(initial_state, [f0_r, c0_r, r0_r, h0_r])
end

# %% [markdown]
# # Simulation Module

# %%
function rounding_procedure(L, DIS)
    a = L[1]
    b = L[2]
    c = L[3]
    d = L[4]
    rou_a = a/DIS
    rou_b = b/DIS
    rou_c = c/DIS
    rou_d = d/DIS
    res = [0.0 for i in 1:4]
    res[1], res[2], res[3], res[4] = rou_a%1, rou_b%1, rou_c%1, rou_d%1
    residual = round(res[1] + res[2] + res[3] + res[4], digits = 0)
    rou_a = floor(rou_a)
    rou_b = floor(rou_b)
    rou_c = floor(rou_c)
    rou_d = floor(rou_d)
    while residual > 0
        max_ind = -1
        max_val = -1
        for i in 1:4
            if res[i] > max_val
                max_val = res[i]
                max_ind = i
            end
        end
        
        if max_ind == 1
            rou_a = rou_a + 1
        elseif max_ind == 2
            rou_b = rou_b + 1
        elseif max_ind == 3
            rou_c = rou_c + 1
        elseif max_ind == 4
            rou_d = rou_d + 1
        end
        
        res[max_ind] = - 1
        residual = residual - 1
    end
    a, b, c, d = round(rou_a*DIS, digits = 2), round(rou_b*DIS, digits = 2), round(rou_c*DIS, digits = 2), round(rou_d*DIS, digits = 2)
    return (a,b,c,d)
end
# Out:
# rounding_procedure (generic function with 1 method)

# %%
function sir(state, x, region)
    wcost = 0
    alpha_r, betaK_r, lambda_r, mu_r = alpha[region], betaK[region], Lambda[region], mu[region]
    f_t, c_t, r_t, h_t = state[1], state[2], state[3], state[4]
    for t in 1:sim_periods
        if (h_t + (alpha_r*f_t - lambda_r*x)*sim_time) >= 0
            f_t_1 = f_t + (-alpha_r*f_t - betaK_r*f_t*(c_t + h_t))*sim_time
            c_t_1 = c_t + (-mu_r*c_t + betaK_r*f_t*(c_t + h_t) + lambda_r*x)*sim_time
            r_t_1 = r_t + (mu_r*c_t)*sim_time
            h_t_1 = h_t + (alpha_r*f_t - lambda_r*x)*sim_time
        else
            cut_zero = alpha_r*f_t + h_t/sim_time
            f_t_1 = f_t + (-alpha_r*f_t - betaK_r*f_t*(c_t + h_t))*sim_time
            c_t_1 = c_t + (-mu_r*c_t + betaK_r*f_t*(c_t + h_t)) + cut_zero)*sim_time
            r_t_1 = r_t + (mu_r*c_t)*sim_time
            h_t_1 = 0
        end
        wcost += (WT*h_t + c_t)*sim_time
        f_t, c_t, r_t, h_t = f_t_1, c_t_1, r_t_1, h_t_1
    end
    L = [f_t, c_t, r_t, h_t]
    f_t, c_t, r_t, h_t = rounding_procedure(L, DIS)
    return (f_t, c_t, r_t, h_t, wcost)
end
# Out:
# sir (generic function with 1 method)

# %% [markdown]
# # Generate the space of all possible states at each Time Period

# %%
function state_space(initial_state)
    #Generate lower bounds for f, h and upper bounds for r
    LB_f = []
    UB_r = []
    LB_h = []
    for i in 1:n_region
        f_min_i = [initial_state[i][1]]
        r_max_i = [initial_state[i][3]]
        h_min_i = [initial_state[i][4]]
        tem_f , tem_c, tem_r, tem_h = initial_state[i][1], initial_state[i][2], initial_state[i][3], initial_state[i][4]
        for time in 1:T
            tem_f, tem_c, tem_r, tem_h, cost = sir([tem_f, tem_c, tem_r, tem_h], VE, i)
            push!(f_min_i, tem_f)
            push!(r_max_i, tem_r)
            push!(h_min_i, tem_h)
        end
        push!(LB_f, f_min_i)
        push!(UB_r, r_max_i)
        push!(LB_h, h_min_i)
    end
    
    #Generate upper bounds for f, h and lower bounds for r
    UB_f = []
    LB_r = []
    UB_h = []    
    for i in 1:n_region
        f_max_i = [initial_state[i][1]]
        r_min_i = [initial_state[i][3]]
        h_max_i = [initial_state[i][4]]
        tem_f , tem_c, tem_r, tem_h = initial_state[i][1], initial_state[i][2], initial_state[i][3], initial_state[i][4]
        for time in 1:T
            tem_f, tem_c, tem_r, tem_h, cost = sir([tem_f, tem_c, tem_r, tem_h], 0, i)
            push!(f_max_i, tem_f)
            push!(r_min_i, tem_r)
            push!(h_max_i, tem_h)
        end
        push!(UB_f, f_max_i)
        push!(LB_r, r_min_i)
        push!(UB_h, h_max_i)
    end
    
    #Now that we have bounds for f, h and r, we can create the whole discretization space
    values_possible = round(1/DIS)
    state_space = []
    number_of_states = 0
    for i in 1:n_region
        state_i = []
        for time in 1:(T+1)
            state_i_time = []
            for v1 in 0:values_possible
                for v2 in 0:(values_possible - v1)
                    for v3 in 0:(values_possible - v1 - v2)
                        v4 = values_possible - v1 - v2 - v3
                        f_el = round(v1*DIS, digits = 2)
                        c_el = round(v2*DIS, digits = 2)
                        r_el = round(v3*DIS, digits = 2)
                        h_el = round(v4*DIS, digits = 2)
                        if (f_el <= UB_f[i][time]) & (f_el >= LB_f[i][time]) & (r_el <= UB_r[i][time]) & (r_el >= LB_r[i][time]) & (h_el <= UB_h[i][time]) & (h_el >= LB_h[i][time])
                            push!(state_i_time, [f_el, c_el, r_el, h_el])
                            number_of_states+=1
                        end
                    end
                end
            end
            push!(state_i, state_i_time)
        end
        push!(state_space, state_i)
    end
    return state_space, number_of_states
end
# Out:
# state_space (generic function with 1 method)

# %%
state_space_fcrh, states_number = state_space(initial_state);

# %% [markdown]
# # Compute all possible transitions and the associated cost

# %%
function DP_All_sim(state_space)
    state_store_next = [[[[[] for x in 0:VE] for s in 1:length(state_space[i][t])] for t in 1:T] for i in 1:n_region]
    state_store_cost = [[[[0.0 for x in 0:VE] for s in 1:length(state_space[i][t])] for t in 1:T] for i in 1:n_region]
    for i in 1:n_region
        count_sim = 0
        Threads.@threads for t in T:-1:1
            for s in 1:length(state_space[i][t])
                x_max = VE
                for x in 0:x_max
                    count_sim += 1
                    f, c, r, h, cost = sir(state_space[i][t][s], x, i)
                    cost = cost*weight[i]
                    next = findall(x-> x==[f, c, r, h], state_space[i][t+1])
                    state_store_next[i][t][s][x+1] = next
                    state_store_cost[i][t][s][x+1] = cost
                end
            end
        end
        println("Region ", i, " runs ", count_sim, " simulations")
    end
    return state_store_next, state_store_cost
end
# Out:
# DP_All_sim (generic function with 1 method)

# %%
state_store_ss1, state_store_cost = DP_All_sim(state_space_fcrh);
# Out:
# Region 1 runs 58124 simulations
# Region 2 runs 27599 simulations
# Region 3 runs 27148 simulations
# Region 4 runs 24398 simulations
# Region 5 runs 25212 simulations
# Region 6 runs 20042 simulations

# %% [markdown]
# # CG Starts Here

# %% [markdown]
# # Add initial columns

# %%
function dummy_columns()
    for i in 1:n_region
    regn_p[record_end[1]] = i
        for t in 1:T
            vehn_pt[record_end[1]][t] = 0
        end
        cost_p[record_end[1]] = 999999
        infea_p[record_end[1]] = false
        record_end[1] += 1
    end
end
# Out:
# dummy_columns (generic function with 1 method)

# %%
function ini_columns(initial_state)
    ini_tot_cost = 0
    for i in 1:n_region
        regn_p[record_end[1]] = i
        tem_f, tem_c, tem_r, tem_h = initial_state[i][1], initial_state[i][2], initial_state[i][3], initial_state[i][4]
        tem_cost = 0
        
        for t in 1:T
            vehn_pt[record_end[1]][t] = 1
            tem_f_1, tem_c_1, tem_r_1, tem_h_1, tem_cost_1 = sir([tem_f, tem_c, tem_r, tem_h], vehn_pt[record_end[1]][t], i)
            tem_f, tem_c, tem_r, tem_h = tem_f_1, tem_c_1, tem_r_1, tem_h_1
            tem_cost += tem_cost_1
        end
        cost_p[record_end[1]] = tem_cost
        infea_p[record_end[1]] = false
        
        ini_tot_cost += cost_p[record_end[1]]*weight[i]
        record_end[1] += 1
    end
    UB[1] = ini_tot_cost
end
# Out:
# ini_columns (generic function with 1 method)

# %% [markdown]
# # Define the Master Problem

# %%
function RMP_define_model()
    RMP = Model(Gurobi.Optimizer)
    set_optimizer_attribute(RMP, "OutputFlag", 0)
    z_p = @variable(RMP, 0 <= z[1:(record_end[1]-1)] <= 1)
    return RMP, z_p
end
# Out:
# RMP_define_model (generic function with 1 method)

# %%
function RMP_add_columns(model, z, c_time, c_region)
    println("RMP begins: Currently, the total number of plans is ", record_end[1] - 1, " from ", record_now[1] - 1)
    #We update the constraints of our model
    if already_optimized[1]
        delete(model, c_time)
        unregister(model, :c_time)
        delete(model, c_region)
        unregister(model, :c_region)
        for p in record_now[1]:(record_end[1]-1)
            push!(z, @variable(model, base_name = "z[$(p)]", lower_bound = 0, upper_bound = 1))
        end
    end
        
    #Select the region for each plan
    for p in record_now[1]:(record_end[1]-1)
        if infea_p[p]
            @constraint(model, z[p] <= 0)
            continue
        end
    end
    
    #VE vehicles can be used at time t
    @constraint(model, c_time[i=1:T], sum(z[p]*vehn_pt[p][i] for p in 1:(record_end[1]-1)) <= R[i])
    
    #One plan per region
    @constraint(model, c_region[i=1:n_region], sum(z[p] for p in 1:(record_end[1]-1) if regn_p[p] == i) == 1)
    
    
    #We update the objective of our model
    @objective(model, Min, sum(weight[regn_p[p]]*z[p]*cost_p[p] for p in 1:(record_end[1]-1)))
    record_now[1] = record_end[1]
    
    optimize!(model)
    
    if termination_status(model) == MOI.OPTIMAL
        Total_cost = objective_value(model)
        println("The optimal objective is ", Total_cost)
        
        pi_ = [dual(c_time[i]) for i in 1:T]
        phi = [dual(c_region[i]) for i in 1:n_region]
        
    else
        println("No Feasible Solution for Gurobi!!!")
    end
    
    negative_column[1] = false
    already_optimized[1] = true
    
    return model, z, pi_, phi, c_time, c_region
end
# Out:
# RMP_add_columns (generic function with 1 method)

# %% [markdown]
# # Pricing Problem to generate the new column to add

# %%
function Backward_DP(region, initial_state, pi, phi, state_space, state_store_next, state_store_cost)
    #We initilize the costs
    state_cost = [[Inf for s in 1:length(state_space[region][t])] for t in 1:(T+1)]
    state_backward = [[0.0 for s in 1:length(state_space[region][t])] for t in 1:T]
    state_decision = [[0.0 for s in 1:length(state_space[region][t])] for t in 1:T]
    
    for s in 1:length(state_space[region][T+1])
        state_cost[T+1][s] = -phi[region]
    end
    
    for t in T:-1:1
        for s in 1:length(state_space[region][t])
            x_max = VE
            min_cost = Inf
            min_state = -1
            min_x = -1
            for x in 0:VE
                if (x < range_it[region][t][1]) | (x > range_it[region][t][2]) #Check Branching Constraints
                    continue
                end
                tem_cost = state_store_cost[region][t][s][x+1]
                tem_next = state_store_next[region][t][s][x+1]
                if length(tem_next) == 0
                    continue
                end
                tem_cost = tem_cost + state_cost[t+1][tem_next[1]] - pi[t]*x
                if tem_cost < min_cost
                    min_cost = tem_cost
                    min_state = tem_next[1]
                    min_x = x
                end
            end
            state_cost[t][s] = min_cost
            state_backward[t][s] = min_state
            state_decision[t][s] = min_x
        end
    end
    
    #We now compute the best decision starting from the initial state
    state_opt = 1
    #println("BackwardDP Opt cost is ", state_cost[1][state_opt], " for region ", region)
    temp_cost = 0
    decision = [0.0 for t in 1:T]
    if state_cost[1][state_opt] < -0.00001
        for t in 1:T
            decision[t] = state_decision[t][state_opt]
            state_opt = state_backward[t][state_opt]
            state_opt = Int(state_opt)
        end  
        
        f, c, r, h = initial_state[region][1], initial_state[region][2], initial_state[region][3], initial_state[region][4]
        for t in 1:T
            f_t, c_t, r_t, h_t, cost_t = sir([f, c, r, h], decision[t], region)
            f, c, r, h = f_t, c_t, r_t, h_t
            temp_cost += cost_t
        end
    end
    
    return decision, temp_cost
end
# Out:
# Backward_DP (generic function with 1 method)

# %%
function BackwardAll(initial_state, pi, phi, state_space, store_next_state, store_state_cost)
    new_plan = []
    cost = []
    for i in 1:n_region #Can do it in Parallel
        plan_i, cost_i = Backward_DP(i, initial_state, pi, phi, state_space, store_next_state, store_state_cost)
        push!(new_plan, plan_i)
        push!(cost, cost_i)
    end
    return new_plan, cost
end
# Out:
# BackwardAll (generic function with 1 method)

# %%
#This gives you the new plan to add to your pool for every region
function extract_column(new_plan, costs)
    for i in 1:n_region
        if costs[i] == 0
            continue
        end
        negative_column[1] = true
        regn_p[record_end[1]] = i
        for t in 1:T
            vehn_pt[record_end[1]][t] = new_plan[i][t]
        end
        cost_p[record_end[1]] = costs[i]
        infea_p[record_end[1]] = false
        record_end[1] += 1
    end
end
# Out:
# extract_column (generic function with 1 method)

# %%
function input()
    record_now[:] = [1]
    record_end[:] = [1]
    negative_column[:] = [false]
    range_it[:] = [[[0, VE] for t in 1:T] for n in 1:n_region]
    lb_node[:] = [0.0 for n in 1:NCOLB]
    pre_node[:] = [1 for n in 1:NCOLB]
    sign_node[:] = [true for n in 1:NCOLB]
    thre_node[:] = [[1, 1, 1.0] for n in 1:NCOLB]
    cur_node[:] = [1]
    tot_node[:] = [0]
    UB[:] = [Inf]
    LB[:] = [-Inf]
    already_optimized[:] = [false]
    c_time[:] = []
    c_region[:] = []
    cost_p[:] = [1.0 for p in 1:Tot_plans]
    vehn_pt[:] = [[1 for t in 1:T] for p in 1:Tot_plans]
    regn_p[:] = [0 for t in 1:Tot_plans]
    infea_p[:] = [true for p in 1:Tot_plans]
    new_cg = [false]
end
# Out:
# input (generic function with 1 method)

# %% [markdown]
# # Column Generation

# %%
function column_generation(initial_state, state_space, store_next_state, store_state_cost, c_time, c_region)
    model, z = RMP_define_model()
    while 1==1
        model, z, pi_, phi, c_time, c_region = RMP_add_columns(model, z, c_time, c_region)
        new_plan, costs = BackwardAll(initial_state, pi_, phi, state_space, store_next_state, store_state_cost)
        extract_column(new_plan, costs)
        println("-----------------------------------------------------")
        if !negative_column[1]
            break
        end
    end
    println("Column Generations Ends")
    println("-----------------------------------------------------")
    return model, z, c_time, c_region
end
# Out:
# column_generation (generic function with 2 methods)

# %%
c_time = []
c_region = []
input()
dummy_columns()
ini_columns(initial_state)
#model, z = RMP_define_model()
time = @elapsed column_generation(initial_state, state_space_fcrh, state_store_ss1, state_store_cost, c_time, c_region);
println(time)
# Out:
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 12 from 0
# The optimal objective is 342.5778020849276
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 18 from 12
# The optimal objective is 320.0697945387827
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 24 from 18
# The optimal objective is 306.1668954588298
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 30 from 24
# The optimal objective is 300.9494766313133
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 36 from 30
# The optimal objective is 295.78401583603073
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 42 from 36
# The optimal objective is 289.964189207376
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 48 from 42
# The optimal objective is 287.2212884980794
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 54 from 48
# The optimal objective is 284.0147181175824
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 60 from 54
# The optimal objective is 276.41939744181497
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 66 from 60
# The optimal objective is 268.6385470481721
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 72 from 66
# The optimal objective is 244.84640874971592
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 78 from 72
# The optimal objective is 240.68827131220775
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 84 from 78
# The optimal objective is 240.1540547076674
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 90 from 84
# The optimal objective is 239.36743453014316
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 95 from 90
# The optimal objective is 238.97600159929644
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 99 from 95
# The optimal objective is 238.707682385382
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 102 from 99
# The optimal objective is 238.65297609320837
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 103 from 102
# The optimal objective is 238.65297609320837
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# 4.048741701

# %% [markdown]
# # Branch & Price Part

# %% [markdown]
# # Algorithm to find the most fractional solution

# %%
function check_fractional_sol(model, z_pi)
    fra_region = -1
    fra_time = -1
    fra_lbval = -1
    
    if termination_status(model) == MOI.OPTIMAL
        LB[1] = objective_value(model)
        assign_it = [[0.0 for t in 1:T] for i in 1:n_region]
        
        #Look at the value the CG assigned to each plan in the end
        for p in 1:record_end[1]
            if infea_p[p]
                continue
            end
            current = value.(z_pi[p])
            if current > 0.00001
                for t in 1:T
                    assign_it[regn_p[p]][t] = assign_it[regn_p[p]][t] + vehn_pt[p][t]*current
                end
            end
        end
        
        #Select the most fractional value, the region and the time period associated with it
        close_gap = 0.5
        middle_point = 0.5
        for i in 1:n_region
            for t in 1:T
                if ((assign_it[i][t]%1) > error_fra) & ((assign_it[i][t]%1) < (1 - error_fra))
                    if abs((assign_it[i][t]%1) - middle_point) < close_gap
                        close_gap = abs((assign_it[i][t]%1) - middle_point)
                        fra_region = i
                        fra_time = t
                        fra_lbval = floor(assign_it[i][t])
                    end
                end
            end
        end
    else
        println("No feasible solution for GUROBI")
    end
    #println("Branching: Region ", fra_region, " period ", fra_time, " floor ", fra_lbval)
    return (Int(round(fra_region)), Int(round(fra_time)), fra_lbval, assign_it)
end
# Out:
# check_fractional_sol (generic function with 1 method)

# %% [markdown]
# # In case the solution is not integer, we must add a branching constraint

# %%
function left_branching()
    fra_region = Int(round(thre_node[cur_node[1]][1]))
    fra_time = Int(round(thre_node[cur_node[1]][2]))
    fra_lbval = thre_node[cur_node[1]][3]
    
    #We add one left branching constraint
    range_it[fra_region][fra_time][2] = min(fra_lbval, range_it[fra_region][fra_time][2])
    
    if range_it[fra_region][fra_time][2] < range_it[fra_region][fra_time][1]
        println("Warnings: Infeasible branching constraints. Left")
    end
    
    #We prune the columns
    for p in 1:(record_end[1]-1)
        #Do not do it for the dummy plans
        if p < n_region + 1
            continue
        end
        
        #Only for the region that is concerned by the new constraint
        if regn_p[p] != fra_region
            continue
        end
        if vehn_pt[p][fra_time] > range_it[fra_region][fra_time][2]
            infea_p[p] = true
        end
    end
end
# Out:
# left_branching (generic function with 1 method)

# %% [markdown]
# # We update the LB and add new constraints

# %%
function best_LB_branching()
    
    range_it[:] = [[[0, VE] for t in 1:T] for n in 1:n_region]
    back_node = cur_node[1]
    
    #We need to add a list of new constraints on the range of vehicles available
    while back_node != 1
        fra_region = Int(round(thre_node[back_node][1]))
        fra_time = Int(round(thre_node[back_node][2]))
        fra_lbval = thre_node[back_node][3]
        fra_sign = sign_node[back_node]
        if fra_sign
            range_it[fra_region][fra_time][2] = min(fra_lbval, range_it[fra_region][fra_time][2]) #We add the left branching constraint
        else
            range_it[fra_region][fra_time][1] = max(fra_lbval, range_it[fra_region][fra_time][1]) #We add the right branching constraint
        end
        
        if range_it[fra_region][fra_time][2] < range_it[fra_region][fra_time][1] # We check that our two branching constraints are feasible
            println("Warnings: Infeasible Branching constraints. BestLB")
        end
        back_node = pre_node[back_node]
    end
    
    #Now we prune the columns
    for p in 1:(record_end[1]-1)
        infea_p[p] = false
        #Done to avoid doing it for the dummy columns at the beginning
        if p < n_region + 1
            continue
        end
        
        #Check wether or not the old plans are still feasible with the new constraints
        i_R = regn_p[p]
        for t in 1:T
            if (vehn_pt[p][t] < range_it[i_R][t][1]) | (vehn_pt[p][t] > range_it[i_R][t][2])
                infea_p[p] = true
                break
            end
        end
    end
end
# Out:
# best_LB_branching (generic function with 1 method)

# %% [markdown]
# # Branch & Price Algorithm

# %%
function branch_and_price(initial_state, state_space, next_states, state_costs)
    BB_nodes = [0]
    best_assign_it = [[0 for t in 1:T] for i in 1:n_region]
    
    c_time = []
    c_region = []
    input()
    dummy_columns()
    ini_columns(initial_state)
    model, z = RMP_define_model()
    
    while 1==1
        popfirst!(BB_nodes)
        
        c_time = []
        c_region = []
        model, z, c_time, c_region = column_generation(initial_state, state_space, next_states, state_costs, c_time, c_region)
        
        fra_region, fra_time, fra_lbval, assign_it = check_fractional_sol(model, z)
        
        if (LB[1] < UB[1]) & (fra_region >= 0) #Solution is still fractional
            println("Branching region: ", fra_region, " in time ", fra_time, " with value ", fra_lbval)
            
            #We add left node first
            tot_node[1] += 1
            lb_node[tot_node[1]] = LB[1]
            pre_node[tot_node[1]] = cur_node[1]
            sign_node[tot_node[1]] = true
            thre_node[tot_node[1]][1] = fra_region
            thre_node[tot_node[1]][2] = fra_time
            thre_node[tot_node[1]][3] = fra_lbval
            insert!(BB_nodes, 1, tot_node[1]) #Depth-first strategy
            
            #We then add the right node
            tot_node[1] += 1
            lb_node[tot_node[1]] = LB[1]
            pre_node[tot_node[1]] = cur_node[1]
            sign_node[tot_node[1]] = false
            thre_node[tot_node[1]][1] = fra_region
            thre_node[tot_node[1]][2] = fra_time
            thre_node[tot_node[1]][3] = fra_lbval + 1
            
            #We rank the nodes according to their lower bound
            for s in 1:length(BB_nodes)
                if s == length(BB_nodes)
                    push!(BB_nodes, tot_node[1])
                    break
                elseif lb_node[tot_node[1]] >= lb_node[BB_nodes[s]]
                    continue
                else
                    insert!(BB_nodes, s, tot_node[1])
                    break
                end
            end
        end
            
        if (LB[1] < UB[1]) & (fra_region < 0) #An integer solution is found
             UB[1] = LB[1] #We update the upper bounds and the decision
            for i in 1:n_region
                for t in 1:T
                    best_assign_it[i][t] = round(assign_it[i][t])
                end
            end
            println("Update UB ", UB[1])
        end
        
        println("Nodes in the queue ", length(BB_nodes), " with UB ", UB[1])
        
        if length(BB_nodes) > 0 #While we still have some nodes on the tree
            if pre_node[BB_nodes[1]] == cur_node[1] #Means we are going for the left branching
                cur_node[1] = BB_nodes[1]
                left_branching()
                println("Proceed left Branching!")
            else #Means that we are going for the lower bound branching
                cur_node[1] = BB_nodes[1]
                best_LB_branching()
                println("Proceed Best LB branching!")
            end
            
        else
            break
        end
        record_now[1] = 1
        already_optimized[1] = false
        #new_cg[1] = true
    end
    
    println("The Optimal solution is ", UB[1])
    
    for i in 1:n_region
        println("Region ", i, ":")
        for t in 1:T
            println(" ", best_assign_it[i][t])
        end
    end
    return best_assign_it
end
# Out:
# branch_and_price (generic function with 1 method)

# %%
c_time = []
c_region = []
@time final_decision = branch_and_price(initial_state, state_space_fcrh, state_store_ss1, state_store_cost);
# Out:
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 12 from 0
# The optimal objective is 342.5778020849276
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 18 from 12
# The optimal objective is 320.0697945387827
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 24 from 18
# The optimal objective is 306.1668954588298
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 30 from 24
# The optimal objective is 300.9494766313133
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 36 from 30
# The optimal objective is 295.78401583603073
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 42 from 36
# The optimal objective is 289.964189207376
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 48 from 42
# The optimal objective is 287.2212884980794
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 54 from 48
# The optimal objective is 284.0147181175824
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 60 from 54
# The optimal objective is 276.41939744181497
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 66 from 60
# The optimal objective is 268.6385470481721
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 72 from 66
# The optimal objective is 244.84640874971592
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 78 from 72
# The optimal objective is 240.68827131220775
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 84 from 78
# The optimal objective is 240.1540547076674
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 90 from 84
# The optimal objective is 239.36743453014316
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 95 from 90
# The optimal objective is 238.97600159929644
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 99 from 95
# The optimal objective is 238.707682385382
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 102 from 99
# The optimal objective is 238.65297609320837
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 103 from 102
# The optimal objective is 238.65297609320837
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 5 in time 2 with value 1.0
# Nodes in the queue 2 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 103 from 0
# The optimal objective is 238.74555324832053
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 105 from 103
# The optimal objective is 238.73259453338665
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 106 from 105
# The optimal objective is 238.73259453338665
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 5 in time 4 with value 3.0
# Nodes in the queue 3 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 106 from 0
# The optimal objective is 238.8081418234373
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 108 from 106
# The optimal objective is 238.80750921729586
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 109 from 108
# The optimal objective is 238.80749343048817
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 2 in time 4 with value 1.0
# Nodes in the queue 4 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 109 from 0
# The optimal objective is 238.98101773315472
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 112 from 109
# The optimal objective is 238.85193513931344
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 1 in time 2 with value 2.0
# Nodes in the queue 5 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 112 from 0
# The optimal objective is 238.88392926074707
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 115 from 112
# The optimal objective is 238.864282143485
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 116 from 115
# The optimal objective is 238.864282143485
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 4 in time 2 with value 0.0
# Nodes in the queue 6 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 116 from 0
# The optimal objective is 238.883929260747
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 1 in time 4 with value 4.0
# Nodes in the queue 7 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 116 from 0
# The optimal objective is 239.5260727872307
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 121 from 116
# The optimal objective is 239.33295567237124
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 122 from 121
# The optimal objective is 239.2637159094122
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 124 from 122
# The optimal objective is 239.26332544865699
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 6 in time 4 with value 0.0
# Nodes in the queue 8 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 124 from 0
# The optimal objective is 239.52891813470256
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 126 from 124
# The optimal objective is 239.52797565576853
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 3 in time 5 with value 0.0
# Nodes in the queue 9 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 126 from 0
# The optimal objective is 239.99459762631233
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 131 from 126
# The optimal objective is 239.85905227977838
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 134 from 131
# The optimal objective is 239.7551643465192
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 136 from 134
# The optimal objective is 239.731093409602
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 1 in time 4 with value 1.0
# Nodes in the queue 10 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 136 from 0
# The optimal objective is 239.81222547022816
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 138 from 136
# The optimal objective is 239.8045342966847
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 142 from 138
# The optimal objective is 239.79905498430514
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 3 in time 3 with value 3.0
# Nodes in the queue 11 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 142 from 0
# The optimal objective is 241.74010648594432
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 148 from 142
# The optimal objective is 240.87632433855597
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 151 from 148
# The optimal objective is 240.51861019660467
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 154 from 151
# The optimal objective is 240.5147472652088
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 155 from 154
# The optimal objective is 240.50264568018898
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 157 from 155
# The optimal objective is 240.4982917196616
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 158 from 157
# The optimal objective is 240.49379587758884
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 5 in time 3 with value 2.0
# Nodes in the queue 12 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 158 from 0
# The optimal objective is 240.89808521063097
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 164 from 158
# The optimal objective is 240.64181205403284
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 165 from 164
# The optimal objective is 240.63147437700968
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 3 in time 4 with value 5.0
# Nodes in the queue 13 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 165 from 0
# The optimal objective is 240.657444717442
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 4 in time 3 with value 2.0
# Nodes in the queue 14 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 165 from 0
# The optimal objective is 240.68924870073153
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 166 from 165
# The optimal objective is 240.68686194433118
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 167 from 166
# The optimal objective is 240.67747545880835
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 3 in time 3 with value 1.0
# Nodes in the queue 15 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 167 from 0
# The optimal objective is 240.8108926189611
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 169 from 167
# The optimal objective is 240.8022864586955
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 170 from 169
# The optimal objective is 240.80164047887232
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 171 from 170
# The optimal objective is 240.80120391336908
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 172 from 171
# The optimal objective is 240.80087748687265
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 4 in time 5 with value 1.0
# Nodes in the queue 16 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 172 from 0
# The optimal objective is 240.83627118063606
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 173 from 172
# The optimal objective is 240.83518309231482
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 1 in time 5 with value 3.0
# Nodes in the queue 17 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 173 from 0
# The optimal objective is 240.91968785661024
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 174 from 173
# The optimal objective is 240.9187642134347
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 2 in time 5 with value 1.0
# Nodes in the queue 18 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 174 from 0
# The optimal objective is 241.02994222061938
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 175 from 174
# The optimal objective is 240.95687195184735
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 2 in time 6 with value 6.0
# Nodes in the queue 19 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 175 from 0
# The optimal objective is 240.9883450888337
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 176 from 175
# The optimal objective is 240.96503934701983
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 1 in time 5 with value 2.0
# Nodes in the queue 20 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 176 from 0
# The optimal objective is 241.3562586030298
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 179 from 176
# The optimal objective is 241.3510112910671
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 2 in time 2 with value 4.0
# Nodes in the queue 21 with UB 342.5778020849276
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 179 from 0
# The optimal objective is 241.3653895344617
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 180 from 179
# The optimal objective is 241.36538953446168
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Update UB 241.36538953446168
# Nodes in the queue 20 with UB 241.36538953446168
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 180 from 0
# The optimal objective is 255.85026295410012
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 186 from 180
# The optimal objective is 239.59969568362968
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 187 from 186
# The optimal objective is 238.94320219706069
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 188 from 187
# The optimal objective is 238.93143939387357
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 189 from 188
# The optimal objective is 238.93143939387355
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 4 in time 2 with value 0.0
# Nodes in the queue 21 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 189 from 0
# The optimal objective is 238.99932469705394
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 190 from 189
# The optimal objective is 238.98565907336697
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 3 in time 5 with value 1.0
# Nodes in the queue 22 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 190 from 0
# The optimal objective is 239.02686700442803
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 3 in time 5 with value 0.0
# Nodes in the queue 23 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 190 from 0
# The optimal objective is 239.585940691029
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 193 from 190
# The optimal objective is 239.37292362791877
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 194 from 193
# The optimal objective is 239.37237253642854
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 195 from 194
# The optimal objective is 239.37221041244055
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 2 in time 5 with value 5.0
# Nodes in the queue 24 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 195 from 0
# The optimal objective is 239.3741006929334
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 3 in time 3 with value 4.0
# Nodes in the queue 25 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 195 from 0
# The optimal objective is 240.07045599897282
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 197 from 195
# The optimal objective is 240.06961295140945
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 5 in time 3 with value 0.0
# Nodes in the queue 26 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 197 from 0
# The optimal objective is 240.2681815109341
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 2 in time 5 with value 3.0
# Nodes in the queue 27 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 197 from 0
# The optimal objective is 240.32162107319476
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 198 from 197
# The optimal objective is 240.31845040932802
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 5 in time 5 with value 1.0
# Nodes in the queue 28 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 198 from 0
# The optimal objective is 240.33217708016292
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 200 from 198
# The optimal objective is 240.32994868297394
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 3 in time 3 with value 1.0
# Nodes in the queue 29 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 200 from 0
# The optimal objective is 240.41323722256877
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 1 in time 4 with value 0.0
# Nodes in the queue 30 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 200 from 0
# The optimal objective is 240.41615892368617
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 2 in time 6 with value 6.0
# Nodes in the queue 31 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 200 from 0
# The optimal objective is 240.43036839231084
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 2 in time 6 with value 5.0
# Nodes in the queue 32 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 200 from 0
# The optimal objective is 240.50586731128024
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 201 from 200
# The optimal objective is 240.44491069401215
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 1 in time 5 with value 6.0
# Nodes in the queue 33 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 201 from 0
# The optimal objective is 240.45495833018592
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 2 in time 3 with value 1.0
# Nodes in the queue 34 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 201 from 0
# The optimal objective is 240.57450977354253
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 4 in time 4 with value 0.0
# Nodes in the queue 35 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 201 from 0
# The optimal objective is 240.98548017322895
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 202 from 201
# The optimal objective is 240.95339685914294
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 203 from 202
# The optimal objective is 240.92255023852334
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 204 from 203
# The optimal objective is 240.92255023852334
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 3 in time 2 with value 2.0
# Nodes in the queue 36 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 204 from 0
# The optimal objective is 240.96704943442498
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 205 from 204
# The optimal objective is 240.96478861605638
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 3 in time 4 with value 2.0
# Nodes in the queue 37 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 205 from 0
# The optimal objective is 241.37061365705205
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 207 from 205
# The optimal objective is 241.17004994997507
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 4 in time 3 with value 2.0
# Nodes in the queue 38 with UB 241.36538953446168
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 207 from 0
# The optimal objective is 241.20249274776853
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 209 from 207
# The optimal objective is 241.1766134357605
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 210 from 209
# The optimal objective is 241.1766134357605
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Update UB 241.1766134357605
# Nodes in the queue 37 with UB 241.1766134357605
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 210 from 0
# The optimal objective is 238.75907504294867
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 4 in time 4 with value 3.0
# Nodes in the queue 38 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 210 from 0
# The optimal objective is 238.81796356215702
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 4 in time 2 with value 1.0
# Nodes in the queue 39 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 210 from 0
# The optimal objective is 238.84260196347896
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 2 in time 4 with value 1.0
# Nodes in the queue 40 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 210 from 0
# The optimal objective is 238.89240364466824
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 1 in time 2 with value 1.0
# Nodes in the queue 41 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 210 from 0
# The optimal objective is 238.92585216701286
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 211 from 210
# The optimal objective is 238.92420052381385
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 3 in time 2 with value 3.0
# Nodes in the queue 42 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 211 from 0
# The optimal objective is 239.32244675936576
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 3 in time 3 with value 4.0
# Nodes in the queue 43 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 211 from 0
# The optimal objective is 239.80601534225966
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 212 from 211
# The optimal objective is 239.79131693949836
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 2 in time 6 with value 6.0
# Nodes in the queue 44 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 212 from 0
# The optimal objective is 239.7927562044692
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 213 from 212
# The optimal objective is 239.7927562044692
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 3 in time 3 with value 0.0
# Nodes in the queue 45 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 213 from 0
# The optimal objective is 239.8247159209557
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 216 from 213
# The optimal objective is 239.82471592095573
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 217 from 216
# The optimal objective is 239.8247159209557
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 2 in time 5 with value 1.0
# Nodes in the queue 46 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 217 from 0
# The optimal objective is 239.82922365074336
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 4 in time 5 with value 1.0
# Nodes in the queue 47 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 217 from 0
# The optimal objective is 239.83988807233996
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 218 from 217
# The optimal objective is 239.83695374904818
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 219 from 218
# The optimal objective is 239.83396984832814
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 220 from 219
# The optimal objective is 239.83122114381084
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 4 in time 3 with value 2.0
# Nodes in the queue 48 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 220 from 0
# The optimal objective is 239.88780651594567
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 221 from 220
# The optimal objective is 239.88759909898815
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 5 in time 3 with value 0.0
# Nodes in the queue 49 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 221 from 0
# The optimal objective is 240.00159264695836
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 222 from 221
# The optimal objective is 240.00159264695833
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 6 in time 4 with value 0.0
# Nodes in the queue 50 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 222 from 0
# The optimal objective is 240.53324865557994
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 223 from 222
# The optimal objective is 240.51550319898598
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 5 in time 2 with value 1.0
# Nodes in the queue 51 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 223 from 0
# The optimal objective is 240.58463936289712
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 224 from 223
# The optimal objective is 240.58463936289712
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 225 from 224
# The optimal objective is 240.58463936289712
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 3 in time 1 with value 1.0
# Nodes in the queue 52 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 225 from 0
# The optimal objective is 241.21358396037112
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 227 from 225
# The optimal objective is 241.1950509285236
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 228 from 227
# The optimal objective is 241.18539805928305
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 51 with UB 241.1766134357605
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 228 from 0
# The optimal objective is 238.7783488517293
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 2 in time 6 with value 6.0
# Nodes in the queue 52 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 228 from 0
# The optimal objective is 238.78618982040544
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 3 in time 1 with value 1.0
# Nodes in the queue 53 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 228 from 0
# The optimal objective is 239.17612299065766
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 229 from 228
# The optimal objective is 239.15990946341785
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 1 in time 3 with value 4.0
# Nodes in the queue 54 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 229 from 0
# The optimal objective is 240.20144067918406
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 231 from 229
# The optimal objective is 239.96596468713372
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 232 from 231
# The optimal objective is 239.9659646871337
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 1 in time 2 with value 4.0
# Nodes in the queue 55 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 232 from 0
# The optimal objective is 240.9024931656109
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 236 from 232
# The optimal objective is 240.48552006638482
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 237 from 236
# The optimal objective is 240.47777751251607
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 1 in time 6 with value 2.0
# Nodes in the queue 56 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 237 from 0
# The optimal objective is 240.76547144647967
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 238 from 237
# The optimal objective is 240.48872063053224
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 5 in time 2 with value 0.0
# Nodes in the queue 57 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 238 from 0
# The optimal objective is 240.57860300630338
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 240 from 238
# The optimal objective is 240.54743339751298
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 5 in time 3 with value 0.0
# Nodes in the queue 58 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 240 from 0
# The optimal objective is 240.56166877308564
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 241 from 240
# The optimal objective is 240.54995749419575
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 242 from 241
# The optimal objective is 240.54995749419575
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 243 from 242
# The optimal objective is 240.54966217591044
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 4 in time 5 with value 0.0
# Nodes in the queue 59 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 243 from 0
# The optimal objective is 240.57860300630338
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 2 in time 2 with value 4.0
# Nodes in the queue 60 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 243 from 0
# The optimal objective is 240.59892718336
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 245 from 243
# The optimal objective is 240.58273671950982
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 2 in time 1 with value 2.0
# Nodes in the queue 61 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 245 from 0
# The optimal objective is 240.61328951674255
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 247 from 245
# The optimal objective is 240.5921000530876
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 1 in time 3 with value 2.0
# Nodes in the queue 62 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 247 from 0
# The optimal objective is 240.66688807012895
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 248 from 247
# The optimal objective is 240.6626950413684
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 3 in time 2 with value 3.0
# Nodes in the queue 63 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 248 from 0
# The optimal objective is 241.44004457734994
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 250 from 248
# The optimal objective is 241.38012864487814
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 251 from 250
# The optimal objective is 241.35721258054704
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 62 with UB 241.1766134357605
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 251 from 0
# The optimal objective is 238.89809597481747
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 253 from 251
# The optimal objective is 238.8125500079034
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 3 in time 1 with value 1.0
# Nodes in the queue 63 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 253 from 0
# The optimal objective is 239.47411754866715
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 255 from 253
# The optimal objective is 239.21333738564263
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 256 from 255
# The optimal objective is 239.21177193096005
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 2 in time 2 with value 3.0
# Nodes in the queue 64 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 256 from 0
# The optimal objective is 240.75599709830453
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 257 from 256
# The optimal objective is 240.37096952567384
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 258 from 257
# The optimal objective is 240.34109930614702
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 2 in time 3 with value 2.0
# Nodes in the queue 65 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 258 from 0
# The optimal objective is 240.71632613923038
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 4 in time 1 with value 3.0
# Nodes in the queue 66 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 258 from 0
# The optimal objective is 240.73376578768176
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 1 in time 5 with value 4.0
# Nodes in the queue 67 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 258 from 0
# The optimal objective is 240.97683273876765
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 259 from 258
# The optimal objective is 240.97672126377196
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Branching region: 1 in time 2 with value 2.0
# Nodes in the queue 68 with UB 241.1766134357605
# Proceed left Branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 259 from 0
# The optimal objective is 241.13626000606035
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 260 from 259
# ...
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 31 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 469 from 0
# The optimal objective is 240.48422850168114
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 470 from 469
# The optimal objective is 240.48422850168114
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 30 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 470 from 0
# The optimal objective is 241.3846437871066
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 471 from 470
# The optimal objective is 240.68896610874003
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 29 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 471 from 0
# The optimal objective is 241.22494998016273
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 472 from 471
# The optimal objective is 241.22063522185704
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 28 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 472 from 0
# The optimal objective is 240.75074802871586
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 473 from 472
# The optimal objective is 240.43956209594182
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 27 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 473 from 0
# The optimal objective is 240.60625735491564
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 474 from 473
# The optimal objective is 240.60365476705124
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 26 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 474 from 0
# The optimal objective is 241.07836741410694
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 475 from 474
# The optimal objective is 241.07836741410694
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 25 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 475 from 0
# The optimal objective is 240.86643690755037
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 476 from 475
# The optimal objective is 240.85842373016501
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 24 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 476 from 0
# The optimal objective is 240.69671948400168
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 477 from 476
# The optimal objective is 240.67539000142668
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 23 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 477 from 0
# The optimal objective is 241.1800567467231
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 478 from 477
# The optimal objective is 241.18005674672312
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 22 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 478 from 0
# The optimal objective is 243.93425433535845
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 481 from 478
# The optimal objective is 242.2918847974421
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 482 from 481
# The optimal objective is 242.20973751695104
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 21 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 482 from 0
# The optimal objective is 241.8465478249937
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 484 from 482
# The optimal objective is 241.7525720024974
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 485 from 484
# The optimal objective is 241.7525720024974
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 20 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 485 from 0
# The optimal objective is 240.8147111803293
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 19 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 485 from 0
# The optimal objective is 240.2369324591489
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 486 from 485
# The optimal objective is 240.21763058084767
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 18 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 486 from 0
# The optimal objective is 242.40747157091914
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 491 from 486
# The optimal objective is 241.88855664664524
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 492 from 491
# The optimal objective is 240.8169158671637
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 17 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 492 from 0
# The optimal objective is 240.7652703718879
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 493 from 492
# The optimal objective is 240.76371809895525
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 16 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 493 from 0
# The optimal objective is 239.88841051491093
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 15 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 493 from 0
# The optimal objective is 240.80984548599736
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 494 from 493
# The optimal objective is 240.7931017263844
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 14 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 494 from 0
# The optimal objective is 240.75138739385565
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 13 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 494 from 0
# The optimal objective is 240.22425743497615
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 12 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 494 from 0
# The optimal objective is 240.0728720475338
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 11 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 494 from 0
# The optimal objective is 240.5773086652797
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 495 from 494
# The optimal objective is 240.5358018789929
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 10 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 495 from 0
# The optimal objective is 241.48353778915012
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 9 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 495 from 0
# The optimal objective is 240.53353091244892
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 496 from 495
# The optimal objective is 240.4862087615264
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 8 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 496 from 0
# The optimal objective is 241.18297980730625
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 7 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 496 from 0
# The optimal objective is 240.7947155537198
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 497 from 496
# The optimal objective is 240.6564898871021
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 6 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 497 from 0
# The optimal objective is 241.7042812360305
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 498 from 497
# The optimal objective is 241.70424941490793
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 5 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 498 from 0
# The optimal objective is 241.7110818827429
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 499 from 498
# The optimal objective is 241.1739911388597
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 4 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 499 from 0
# The optimal objective is 243.22070026897833
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 504 from 499
# The optimal objective is 241.68392692911965
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 505 from 504
# The optimal objective is 241.62175139328005
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 3 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 505 from 0
# The optimal objective is 241.5247946238198
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 2 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 505 from 0
# The optimal objective is 241.61275562226382
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 506 from 505
# The optimal objective is 241.60539726451506
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 1 with UB 238.99024140676119
# Proceed Best LB branching!
# Academic license - for non-commercial use only
# RMP begins: Currently, the total number of plans is 506 from 0
# The optimal objective is 241.2964780527018
# -----------------------------------------------------
# RMP begins: Currently, the total number of plans is 507 from 506
# The optimal objective is 241.29044235877484
# -----------------------------------------------------
# Column Generations Ends
# -----------------------------------------------------
# Nodes in the queue 0 with UB 238.99024140676119
# The Optimal solution is 238.99024140676119
# Region 1:
#  2
#  1
#  5
#  5
#  2
#  2
# Region 2:
#  2
#  4
#  0
#  0
#  5
#  6
# Region 3:
#  3
#  2
#  5
#  0
#  1
#  2
# Region 4:
#  2
#  3
#  0
#  0
#  1
#  0
# Region 5:
#  0
#  0
#  0
#  5
#  0
#  0
# Region 6:
#  1
#  0
#  0
#  0
#  1
#  0
#  86.013689 seconds (459.40 M allocations: 9.498 GiB, 4.57% gc time)

# %%
println("Region 1")
println([2,1, 5, 5, 2, 2])
println("Region 2")
println([2, 4, 0, 0, 5, 6])
println("Region 3")
println([3 , 2, 5, 0, 1, 2])
println("Region 4")
println([2, 3, 0, 0, 1, 0])
println("Region 5")
println([0, 0, 0, 5, 0, 0])
println("Region 6")
println([1, 0, 0, 0, 1, 0])
# Out:
# Region 1
# [2, 1, 5, 5, 2, 2]
# Region 2
# [2, 4, 0, 0, 5, 6]
# Region 3
# [3, 2, 5, 0, 1, 2]
# Region 4
# [2, 3, 0, 0, 1, 0]
# Region 5
# [0, 0, 0, 5, 0, 0]
# Region 6
# [1, 0, 0, 0, 1, 0]
